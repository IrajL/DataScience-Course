# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ![2-title.PNG](attachment:64690ec4-7f68-4674-b6d9-74eb3eff7547.PNG)

# %% [markdown]
# ![3-intro.PNG](attachment:4aadacfa-1a5f-4c7b-beb1-c3f14254baa0.PNG)

# %% [markdown]
# ![10-objectives.PNG](attachment:92eb41c4-cb59-4490-9304-29580dc0abe3.PNG)

# %% [markdown]
# ![4-dslanguages.PNG](attachment:5e7e386c-af7e-4b30-b5d9-89a53e9070ce.PNG)

# %% [markdown]
# ![5-dslibraries.PNG](attachment:c324edbd-bd8d-476a-bd21-f6d7f4b59874.PNG)

# %% [markdown]
# ![6-dstools.PNG](attachment:d34008f9-1361-4477-83d7-20dbc69138cd.PNG)

# %% [markdown]
# ![7-introarithmetic.PNG](attachment:20e24c8a-738b-45ef-9659-e3d90acc7c7b.PNG)

# %% [markdown]
# ![8-multiplyandaddintegers.PNG](attachment:db013f68-cd3f-4824-9de1-0be41625795e.PNG)

# %% [markdown]
# ![9-hourstominutes.PNG](attachment:c3942365-e432-41b7-ae81-fa81d6c45f37.PNG)

# %% [markdown]
# ![11-authordetails.PNG](attachment:ec776627-b45c-42f0-a75c-0926e62b36fb.PNG)

# %% [markdown]
# ### <span style="color:#7095C2">Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)</span>

# %% [markdown]
# ![1-notebook.PNG](attachment:309ef052-aec7-4af5-9f66-5845cb0f23c4.PNG)
